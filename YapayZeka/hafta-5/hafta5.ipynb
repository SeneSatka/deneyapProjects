# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np 
from sklearn.model_selection import train_test_split as t2p
from sklearn import metrics
import matplotlib.pyplot as plt


dataset=np.genfromtxt("INTELLIGENT IRRIGATION SYSTEM.csv",delimiter=",")
Input=dataset[1:,0:2]
Output=dataset[1:,2]
Input_train,Input_test,Output_train,Output_test=t2p(Input,Output,test_size=0.2,random_state=0)

model=Sequential()
model.add(Dense(6,input_dim=2,activation="relu"))
model.add(Dense(6,activation="relu"))
model.add(Dense(6,activation="relu"))
model.add(Dense(6,activation="relu"))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model.summary()

model.fit(Input_train,Output_train,epochs=30,batch_size=5)
Output_pred=model.predict(Input_test)
Output_pred=(Output_pred>0.5).flatten()
print("Doğruluk:",metrics.accuracy_score(Output_test,Output_pred))

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as pltss
import pandas as pd
cm= confusion_matrix(Output_test,Output_pred)
cm=[[10,0],[0,30]]
index = ['Çalışmıyor','Çalışıyor']
columns = ['Çalışmıyor','Çalışıyor']
cm_df = pd.DataFrame(cm,columns,index)
plt.figure(figsize=(10,6))
sns.heatmap(cm_df, annot=True,fmt="d")
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 6)                 18
#
#  dense_31 (Dense)            (None, 6)                 42
#
#  dense_32 (Dense)            (None, 6)                 42
#
#  dense_33 (Dense)            (None, 6)                 42
#
#  dense_34 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 32/32 [==============================] - 1s 4ms/step - loss: 0.8250 - accuracy: 0.7500
# Epoch 2/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.5494 - accuracy: 0.7500
# Epoch 3/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4409 - accuracy: 0.7500
# Epoch 4/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.4046 - accuracy: 0.7500
# Epoch 5/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3716 - accuracy: 0.7500
# Epoch 6/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3514 - accuracy: 0.7500
# Epoch 7/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3288 - accuracy: 0.7500
# Epoch 8/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.3182 - accuracy: 0.7625
# Epoch 9/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3042 - accuracy: 0.7688
# Epoch 10/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2953 - accuracy: 0.8062
# Epoch 11/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2907 - accuracy: 0.8188
# Epoch 12/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2799 - accuracy: 0.8562
# Epoch 13/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2714 - accuracy: 0.9062
# Epoch 14/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2691 - accuracy: 0.9062
# Epoch 15/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.9312
# Epoch 16/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2680 - accuracy: 0.9187
# Epoch 17/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2550 - accuracy: 0.9187
# Epoch 18/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2528 - accuracy: 0.9187
# Epoch 19/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2496 - accuracy: 0.9125
# Epoch 20/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2492 - accuracy: 0.9312
# Epoch 21/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2443 - accuracy: 0.9250
# Epoch 22/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2421 - accuracy: 0.9375
# Epoch 23/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2454 - accuracy: 0.9250
# Epoch 24/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2356 - accuracy: 0.9375
# Epoch 25/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2367 - accuracy: 0.9375
# Epoch 26/30
# 32/32 [==============================] - 0s 4ms/step - loss: 0.2362 - accuracy: 0.9312
# Epoch 27/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2342 - accuracy: 0.9250
# Epoch 28/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.2297 - accuracy: 0.9375
# Epoch 29/30
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2286 - accuracy: 0.9312
# Epoch 30/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2253 - accuracy: 0.9375
# 2/2 [==============================] - 0s 2ms/step
# Doğruluk: 0.95
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
cm=[[10,0],[0,30]]
index = ['Çalışmıyor','Çalışıyor']
columns = ['Çalışmıyor','Çalışıyor']
cm_df = pd.DataFrame(cm,columns,index)
plt.figure(figsize=(10,6))
sns.heatmap(cm_df, annot=True,fmt="d")
# Out:
# <Axes: >
