# %%
import pygad
import numpy
function_inputs=[4,-2,5.5,-11,-4.7]
desired_output=44
def fitness_func(self,solution,solution_idx):
    output=numpy.sum(solution*function_inputs)
    fitness=1.0/numpy.abs(output-desired_output)
    return fitness
fitness_function=fitness_func
num_generations=100
num_parents_mating=7

sol_per_pop=50
num_genes=len(function_inputs)
last_fitness=0
def nesil_ozeti(ga_instance):
    global last_fitness
    print("Nesil = {generation}".format(generation=ga_instance.generations_completed))
    print("Fonksiyon Sonucu = {fitness}".format(fitness=ga_instance.best_solution()[1]))
    print("Degisim = {change}".format(change=(ga_instance.best_solution()[1]-last_fitness)))
    last_fitness=ga_instance.best_solution()[1]
ga_instance=pygad.GA(num_generations=num_generations,num_parents_mating=num_parents_mating,fitness_func=fitness_function,sol_per_pop=sol_per_pop,num_genes=num_genes,on_generation=nesil_ozeti)
ga_instance.run()
solution,solution_fitness,solution_idx=ga_instance.best_solution()
print("En uygun cozum degisken degerleri : {solution}".format(solution=solution))
print("En uygun cozumu veren birey indeks no : {solution_idx}".format(solution_idx=solution_idx))

prediction=numpy.sum(numpy.array(function_inputs)*solution)
print("En uygun cozum ile fonksiyon sonucu : {prediction}".format(prediction=prediction))

if ga_instance.best_solution_generation != -1:
    print("En uygun cozum {best_solution_generation} nesil sonra elde edildi".format(best_solution_generation=ga_instance.best_solution_generation))
# Out:
# /home/senesatka/.conda/envs/tf/lib/python3.10/site-packages/pygad/pygad.py:728: UserWarning: The percentage of genes to mutate (mutation_percent_genes=10) resutled in selecting (0) genes. The number of genes to mutate is set to 1 (mutation_num_genes=1).
# If you do not want to mutate any gene, please set mutation_type=None.
#   warnings.warn(
# Nesil = 1
# Fonksiyon Sonucu = 1.312729284132379
# Degisim = 1.312729284132379
# Nesil = 2
# Fonksiyon Sonucu = 17.05108653149043
# Degisim = 15.738357247358051
# Nesil = 3
# Fonksiyon Sonucu = 17.05108653149043
# Degisim = 0.0
# Nesil = 4
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 31.58540445527724
# Nesil = 5
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 6
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 7
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 8
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 9
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 10
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 11
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 12
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 13
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 14
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 15
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 16
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 17
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 18
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 19
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 20
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 21
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 22
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 23
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 24
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 25
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 26
# Fonksiyon Sonucu = 48.63649098676767
# Degisim = 0.0
# Nesil = 27
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 460.3881193848044
# Nesil = 28
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 29
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 30
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 31
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 32
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 33
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 34
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 35
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 36
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 37
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 38
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 39
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 40
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 41
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 42
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 43
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 44
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 45
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 46
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 47
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 48
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 49
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 50
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 51
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 52
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 53
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 54
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 55
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 56
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 57
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 58
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 59
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 60
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 61
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 62
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 63
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 64
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 65
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 66
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 67
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 68
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 69
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 70
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 71
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 72
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 73
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 74
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 75
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 76
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 77
# Fonksiyon Sonucu = 509.02461037157207
# Degisim = 0.0
# Nesil = 78
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 314.1393654438899
# Nesil = 79
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 80
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 81
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 82
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 83
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 84
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 85
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 86
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 87
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 88
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 89
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 90
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 91
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 92
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 93
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 94
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 95
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 96
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 97
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 98
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 99
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# Nesil = 100
# Fonksiyon Sonucu = 823.163975815462
# Degisim = 0.0
# En uygun cozum degisken degerleri : [ 2.21094392  0.93451704  0.41421195 -2.7948671  -0.85207861]
# En uygun cozumu veren birey indeks no : 0
# En uygun cozum ile fonksiyon sonucu : 44.00121482478507
# En uygun cozum 78 nesil sonra elde edildi
